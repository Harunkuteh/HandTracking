# %%
import cv2
from cvzone.HandTrackingModule import HandDetector

# เปิดกล้อง
cap = cv2.VideoCapture(0)
detector = HandDetector(detectionCon=0.8, maxHands=2)  # ตั้งค่าความแม่นยำ

while True:
    ret, frame = cap.read()
    if ret:
        frame = cv2.resize(frame, (960, 720))
        hands, frame = detector.findHands(frame)  # ตรวจจับมือ
        
        if hands:
            for hand in hands:
                if hand["type"] == "Right":
                    fingers = detector.fingersUp(hand)
                    fingerCount = fingers.count(1)
                    cv2.putText(frame, f'Fingers: {fingerCount}', (10, 100),
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 3)
        
        cv2.imshow("frame", frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):  # กด 'q' เพื่อปิด
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### 📷 Hand Detection Example:
#
# <img src="https://assets.onecompiler.app/433gecjsy/43ar8hwtj/1.png" alt="Hand Tracking Example" width="300">

# %%
import cv2
from cvzone.HandTrackingModule import HandDetector

# เปิดกล้อง
cap = cv2.VideoCapture(0)
detector = HandDetector(detectionCon=0.8, maxHands=2)  # ตั้งค่าความแม่นยำ

while True:
    ret, frame = cap.read()
    if ret:
        frame = cv2.resize(frame, (960, 720))
        hands, frame = detector.findHands(frame)  # ตรวจจับมือ
        
        if hands:
            for hand in hands:
                fingers = detector.fingersUp(hand)
                fingerCount = fingers.count(1)
                handType = hand["type"]  # "Left" หรือ "Right"

                if handType == "Right":
                    text = f'Right Hand: {fingerCount}'
                    position = (10, 100)
                    color = (0, 0, 255)  # สีแดง
                else:
                    text = f'Left Hand: {fingerCount}'
                    position = (10, 150)
                    color = (255, 0, 0)  # สีน้ำเงิน

                cv2.putText(frame, text, position, 
                            cv2.FONT_HERSHEY_SIMPLEX, 1, color, 3)

        cv2.imshow("frame", frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):  # กด 'q' เพื่อปิด
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### 📷 Hand Detection Example:
#
# <img src="https://assets.onecompiler.app/433gecjsy/43ar8hwtj/2.png" alt="Hand Tracking Example" width="300">

# %%
import cv2
from cvzone.HandTrackingModule import HandDetector

# เปิดกล้อง
cap = cv2.VideoCapture(0)
detector = HandDetector(detectionCon=0.8, maxHands=2)  # ตั้งค่าความแม่นยำ

# สร้างหน้าต่างแบบเต็มจอ
cv2.namedWindow("frame", cv2.WND_PROP_FULLSCREEN)
cv2.setWindowProperty("frame", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

while True:
    ret, frame = cap.read()
    if ret:
        frame = cv2.resize(frame, (1920, 1080))  # ปรับขนาดเป็น Full HD
        hands, frame = detector.findHands(frame)  # ตรวจจับมือ
        
        if hands:
            for hand in hands:
                fingers = detector.fingersUp(hand)
                fingerCount = fingers.count(1)
                handType = hand["type"]  # "Left" หรือ "Right"

                if handType == "Right":
                    text = f'Right Hand: {fingerCount}'
                    position = (50, 150)
                    color = (0, 0, 255)  # สีแดง
                else:
                    text = f'Left Hand: {fingerCount}'
                    position = (50, 250)
                    color = (255, 0, 0)  # สีน้ำเงิน

                cv2.putText(frame, text, position, 
                            cv2.FONT_HERSHEY_SIMPLEX, 2, color, 5)

        cv2.imshow("frame", frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):  # กด 'q' เพื่อปิด
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### 📷 Hand Detection Example:
# ##### Resize to Full HD
#
# <img src="https://assets.onecompiler.app/433gecjsy/43ar8hwtj/3.png" alt="Hand Tracking Example" width="300">

# %%
import cv2
from cvzone.HandTrackingModule import HandDetector

# เปิดกล้อง
cap = cv2.VideoCapture(0)
detector = HandDetector(detectionCon=0.8, maxHands=2)  # ตั้งค่าความแม่นยำ

# รายชื่อนิ้วมือ
finger_names = ["Thumb", "Index", "Middle", "Ring", "Pinky"]

# สร้างหน้าต่างแบบเต็มจอ
cv2.namedWindow("frame", cv2.WND_PROP_FULLSCREEN)
cv2.setWindowProperty("frame", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

while True:
    ret, frame = cap.read()
    if ret:
        frame = cv2.resize(frame, (1920, 1080))  # ปรับขนาดเป็น Full HD
        hands, frame = detector.findHands(frame)  # ตรวจจับมือ
        
        if hands:
            for hand in hands:
                fingers = detector.fingersUp(hand)
                fingerCount = fingers.count(1)
                handType = hand["type"]  # "Left" หรือ "Right"

                # กำหนดสีให้มือซ้ายเป็นเขียว และมือขวาเป็นแดง
                if handType == "Right":
                    text = f'Right Hand: {fingerCount} fingers'
                    position = (50, 150)
                    color = (0, 0, 255)  # สีแดง
                else:
                    text = f'Left Hand: {fingerCount} fingers'
                    position = (50, 250)
                    color = (0, 255, 0)  # สีเขียว

                # แสดงจำนวนของนิ้วที่ยกขึ้น
                cv2.putText(frame, text, position, 
                            cv2.FONT_HERSHEY_SIMPLEX, 2, color, 5)

                # แสดงชื่อของนิ้วที่ยกขึ้น
                up_fingers = [finger_names[i] for i in range(5) if fingers[i] == 1]
                if up_fingers:
                    fingers_text = " | ".join(up_fingers)
                    cv2.putText(frame, fingers_text, (position[0], position[1] + 60), 
                                cv2.FONT_HERSHEY_SIMPLEX, 1.5, color, 4)

        cv2.imshow("frame", frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):  # กด 'q' เพื่อปิด
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### 📷 Hand Detection Example:
# ##### Displays the number of fingers raised.
# ##### Displays the name of the raised finger.
# ##### Set the color of the left hand to be green and the right hand to be red.
#
# <img src="https://assets.onecompiler.app/433gecjsy/43ar8hwtj/4.png" alt="Hand Tracking Example" width="300">

# %%
import cv2
import numpy as np
from cvzone.HandTrackingModule import HandDetector

# เปิดกล้อง
cap = cv2.VideoCapture(0)
detector = HandDetector(detectionCon=0.8, maxHands=2)  # ตั้งค่าความแม่นยำ

# รายชื่อนิ้วมือ
finger_names = ["Thumb", "Index", "Middle", "Ring", "Pinky"]

# สร้างหน้าต่างแบบเต็มจอ
cv2.namedWindow("frame", cv2.WND_PROP_FULLSCREEN)
cv2.setWindowProperty("frame", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

while True:
    ret, frame = cap.read()
    if ret:
        frame = cv2.resize(frame, (1920, 1080))  # ปรับขนาดเป็น Full HD
        hands, frame = detector.findHands(frame)  # ตรวจจับมือ

        # สร้างพื้นหลังโปร่งใสเพื่อให้ข้อความอ่านง่าย
        overlay = frame.copy()
        cv2.rectangle(overlay, (30, 100), (500, 400), (0, 0, 0), -1)  # กล่องข้อความโปร่งใส
        cv2.addWeighted(overlay, 0.5, frame, 0.5, 0, frame)

        if hands:
            y_offset = 130  # ตำแหน่ง Y เริ่มต้นของข้อความ
            for hand in hands:
                fingers = detector.fingersUp(hand)
                fingerCount = fingers.count(1)
                handType = hand["type"]  # "Left" หรือ "Right"

                # กำหนดสีให้มือซ้ายเป็นเขียว และมือขวาเป็นแดง
                if handType == "Right":
                    text = f'Right Hand: {fingerCount} fingers'
                    color = (0, 0, 255)  # สีแดง
                else:
                    text = f'Left Hand: {fingerCount} fingers'
                    color = (0, 255, 0)  # สีเขียว

                # แสดงจำนวนของนิ้วที่ยกขึ้น
                cv2.putText(frame, text, (50, y_offset), 
                            cv2.FONT_HERSHEY_SIMPLEX, 1.5, color, 4)
                y_offset += 50  # เลื่อนลงบรรทัดใหม่

                # แสดงชื่อของนิ้วที่ยกขึ้น
                up_fingers = [finger_names[i] for i in range(5) if fingers[i] == 1]
                if up_fingers:
                    fingers_text = " | ".join(up_fingers)
                    cv2.putText(frame, fingers_text, (50, y_offset), 
                                cv2.FONT_HERSHEY_SIMPLEX, 1, color, 3)
                    y_offset += 50  # เลื่อนลงอีกบรรทัด

        cv2.imshow("frame", frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):  # กด 'q' เพื่อปิด
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### 📷 Hand Detection Example:
# ##### Align text
#
# <img src="https://assets.onecompiler.app/433gecjsy/43ar8hwtj/5.png" alt="Hand Tracking Example" width="300">

# %%
import cv2
from cvzone.HandTrackingModule import HandDetector

# เปิดกล้อง
cap = cv2.VideoCapture(0)
detector = HandDetector(detectionCon=0.8)

# รายชื่อนิ้วมือ
fingerNames = ["Thumb", "Index", "Middle", "Ring", "Pinky"]

# ตั้งค่าหน้าต่างเป็น Fullscreen
cv2.namedWindow("Hand Tracking", cv2.WND_PROP_FULLSCREEN)
cv2.setWindowProperty("Hand Tracking", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    hands, frame = detector.findHands(frame)  # ตรวจจับมือ

    if hands:
        y_position = 50  # ตำแหน่งเริ่มต้นของข้อความ
        for hand in hands:
            handType = hand["type"]  # ซ้ายหรือขวา
            fingers = detector.fingersUp(hand)  # ตรวจสอบนิ้วที่ยกขึ้น
            fingerCount = fingers.count(1)  # นับนิ้วที่ยกขึ้น

            # รายชื่อนิ้วที่ถูกยกขึ้น
            raisedFingers = [fingerNames[i] for i in range(5) if fingers[i] == 1]
            raisedFingersText = ", ".join(raisedFingers) if raisedFingers else "None"

            # กำหนดสีให้มือซ้ายเป็นเขียว มือขวาเป็นน้ำเงิน
            color = (0, 255, 0) if handType == "Left" else (255, 0, 0)

            # แสดงข้อมูล
            cv2.putText(frame, f'{handType} Hand - Fingers: {fingerCount}', (20, y_position),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, color, 3, cv2.LINE_AA)
            y_position += 40
            cv2.putText(frame, f'Raised: {raisedFingersText}', (20, y_position),
                        cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 3, cv2.LINE_AA)
            y_position += 50  # ขยับลงเพื่อไม่ให้ข้อความทับกัน

    # แสดงผลวิดีโอ
    cv2.imshow("Hand Tracking", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):  # กด 'q' เพื่อปิดโปรแกรม
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### 📷 Hand Detection Example:
# ##### Align text a big size
#
# <img src="https://assets.onecompiler.app/433gecjsy/43ar8hwtj/6.png" alt="Hand Tracking Example" width="300">

# %%
import cv2
from cvzone.HandTrackingModule import HandDetector

# เปิดกล้อง
cap = cv2.VideoCapture(0)
detector = HandDetector(detectionCon=0.8)

# รายชื่อนิ้วมือ
fingerNames = ["Thumb", "Index", "Middle", "Ring", "Pinky"]

# ตั้งค่าหน้าต่างเป็น Fullscreen
cv2.namedWindow("Hand Tracking", cv2.WND_PROP_FULLSCREEN)
cv2.setWindowProperty("Hand Tracking", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    hands, frame = detector.findHands(frame)  # ตรวจจับมือ

    if hands:
        y_position = 30  # ตำแหน่งเริ่มต้นของข้อความ
        for hand in hands:
            handType = hand["type"]  # ซ้ายหรือขวา
            fingers = detector.fingersUp(hand)  # ตรวจสอบนิ้วที่ยกขึ้น
            fingerCount = fingers.count(1)  # นับนิ้วที่ยกขึ้น

            # รายชื่อนิ้วที่ถูกยกขึ้น
            raisedFingers = [fingerNames[i] for i in range(5) if fingers[i] == 1]
            raisedFingersText = ", ".join(raisedFingers) if raisedFingers else "None"

            # กำหนดสีให้มือซ้ายเป็นเขียว มือขวาเป็นน้ำเงิน
            color = (0, 255, 0) if handType == "Left" else (255, 0, 0)

            # แสดงข้อมูล (ขนาดตัวอักษรเล็กลง)
            cv2.putText(frame, f'{handType} Hand - {fingerCount} fingers', (20, y_position),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2, cv2.LINE_AA)
            y_position += 25
            cv2.putText(frame, f'Raised: {raisedFingersText}', (20, y_position),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2, cv2.LINE_AA)
            y_position += 30  # ขยับลงเพื่อไม่ให้ข้อความทับกัน

    # แสดงผลวิดีโอ
    cv2.imshow("Hand Tracking", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):  # กด 'q' เพื่อปิดโปรแกรม
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### 📷 Hand Detection Example:
# ##### Size your text to make it small and look good.
# <img src="https://assets.onecompiler.app/433gecjsy/43ar8hwtj/Hand%20Tracking.png" alt="Hand Tracking Example" width="300">

# %%
import cv2
from cvzone.HandTrackingModule import HandDetector

# เปิดกล้อง
cap = cv2.VideoCapture(0)
detector = HandDetector(detectionCon=0.9, maxHands=2)  # เพิ่มความแม่นยำในการตรวจจับ

# รายชื่อนิ้วมือ
fingerNames = ["Thumb", "Index", "Middle", "Ring", "Pinky"]

# ตั้งค่าหน้าต่างเป็น Fullscreen
cv2.namedWindow("Hand Tracking", cv2.WND_PROP_FULLSCREEN)
cv2.setWindowProperty("Hand Tracking", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.flip(frame, 1)  # ทำการกลับภาพให้ถูกต้อง (mirror effect)
    
    hands, frame = detector.findHands(frame)  # ตรวจจับมือ

    if hands:
        y_position = 30  # ตำแหน่งเริ่มต้นของข้อความ
        for hand in hands:
            handType = hand["type"]  # ซ้ายหรือขวา
            fingers = detector.fingersUp(hand)  # ตรวจสอบนิ้วที่ยกขึ้น
            fingerCount = fingers.count(1)  # นับนิ้วที่ยกขึ้น

            # รายชื่อนิ้วที่ถูกยกขึ้น
            raisedFingers = [fingerNames[i] for i in range(5) if fingers[i] == 1]
            raisedFingersText = ", ".join(raisedFingers) if raisedFingers else "None"

            # กำหนดสีให้มือซ้ายเป็นเขียว มือขวาเป็นน้ำเงิน
            color = (0, 255, 0) if handType == "Left" else (255, 0, 0)

            # แสดงข้อมูล (ขนาดตัวอักษรเล็กลง)
            cv2.putText(frame, f'{handType} Hand - {fingerCount} fingers', (20, y_position),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2, cv2.LINE_AA)
            y_position += 25
            cv2.putText(frame, f'Raised: {raisedFingersText}', (20, y_position),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2, cv2.LINE_AA)
            y_position += 30  # ขยับลงเพื่อไม่ให้ข้อความทับกัน

    # แสดงผลวิดีโอ
    cv2.imshow("Hand Tracking", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):  # กด 'q' เพื่อปิดโปรแกรม
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 🖐 Hand Tracking Project 🖐

# %% [markdown]
# # Business Understanding
# ### 🎯 Project Objectives
# This project is a real-time hand tracking system using OpenCV and cvzone.
# It can be applied to various applications that require hand gesture recognition, such as:
# - 💻 Hands-free control for user interfaces
# - 🎮 Interactive gaming experiences and simulations
# - 👨‍👩‍👧‍👦 Enhancing communication tools for people with disabilities

# %% [markdown]
# # Data Understanding
# #### Data Source:
# The system uses a real-time video feed captured from a webcam.
# #### Key Data Points:
# - 📍 Hand Landmarks: Position and orientation of key points on the hand.
# - ✋ Finger Count: The number of raised fingers.
# - 🔄 Hand Type: Distinguishes between the left and right hands.

# %% [markdown]
# ## Example of Hand Detection
# <img src="https://assets.onecompiler.app/433gecjsy/43ar8hwtj/Hand%20Tracking.png" alt="Hand Tracking Example" width="500">

# %% [markdown]
# # Data Preparation
# ### Preparation Steps:
#
# - 🔍 Camera Check: Ensure the webcam is working properly.
# - 🤖 Hand Detection Verification: Confirm that the system correctly identifies hand positions and gestures.

# %% [markdown]
# ## Camera Check Example

# %%
import cv2

cap = cv2.VideoCapture(0)
ret, frame = cap.read()
print("✅ Camera is working" if ret else "❌ Camera not found")
cap.release()
# Out:
# ✅ Camera is working

# %% [markdown]
# ## Hand Detection Verification

# %%
import cv2
from cvzone.HandTrackingModule import HandDetector

cap = cv2.VideoCapture(0)
detector = HandDetector(detectionCon=0.9, maxHands=2)
ret, frame = cap.read()
hands, frame = detector.findHands(frame)

if hands:
    for hand in hands:
        print(f"👍 Successfully detected {hand['type']} hand!")
cap.release()
# Out:
# 👍 Successfully detected Left hand!

# %% [markdown]
# # Modeling

# %% [markdown]
# ### Core Implementation:
# The model detects hands, counts raised fingers, and distinguishes between left and right hands.
#
# ### Features:
#
# - 🔄 Mirror Effect: Flips the video frame for a natural mirror view.
# - 📝 Dynamic Text Display: Shows hand type, finger count, and raised finger names in real time.

# %% [markdown]
# ## Main Code

# %%
import cv2
from cvzone.HandTrackingModule import HandDetector

# Open the camera
cap = cv2.VideoCapture(0)
detector = HandDetector(detectionCon=0.9, maxHands=2)

# List of finger names
fingerNames = ["Thumb", "Index", "Middle", "Ring", "Pinky"]

# Set the window to Fullscreen
cv2.namedWindow("Hand Tracking", cv2.WND_PROP_FULLSCREEN)
cv2.setWindowProperty("Hand Tracking", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.flip(frame, 1)  # 🔄 Mirror the frame
    hands, frame = detector.findHands(frame)  # 🤖 Detect hands

    if hands:
        y_position = 30  # Starting vertical position for text
        for hand in hands:
            handType = hand["type"]  # Left or Right
            fingers = detector.fingersUp(hand)  # Check raised fingers
            fingerCount = fingers.count(1)  # Count raised fingers

            # List of raised fingers
            raisedFingers = [fingerNames[i] for i in range(5) if fingers[i] == 1]
            raisedFingersText = ", ".join(raisedFingers) if raisedFingers else "None"

            # Set text color: green for left hand, blue for right hand
            color = (0, 255, 0) if handType == "Left" else (255, 0, 0)

            # Display hand type and finger count
            cv2.putText(frame, f'{handType} Hand - {fingerCount} fingers', (20, y_position),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2, cv2.LINE_AA)
            y_position += 25
            # Display which fingers are raised
            cv2.putText(frame, f'Raised: {raisedFingersText}', (20, y_position),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2, cv2.LINE_AA)
            y_position += 30  # Prevent text overlap

    # Show the video
    cv2.imshow("Hand Tracking", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Evaluation
# - **📈 Accuracy:** ~90% correct detection of hand gestures.
# - **💪 Strengths:**
#   - Correct identification of raised fingers.
#   - Clear distinction between left and right hands.
# - **⚠️ Issues:**
#   - Inaccurate detection in low-light conditions.
#   - Errors when the hand is at an extreme angle.

# %% [markdown]
# # Deployment
# Potential deployment areas include:
# - 🖥️ Gesture-based control for interactive systems.
# - 📱 Touchless UI/UX applications.
# - ♿ Assistive technology for individuals with disabilities.
# - 🎮 Integration with VR/AR platforms.

# %% [markdown]
# # Result

# %%
import cv2
from cvzone.HandTrackingModule import HandDetector

# Open the camera
cap = cv2.VideoCapture(0)
detector = HandDetector(detectionCon=0.9, maxHands=2)

# List of finger names
fingerNames = ["Thumb", "Index", "Middle", "Ring", "Pinky"]

# Set the window to Fullscreen
cv2.namedWindow("Hand Tracking", cv2.WND_PROP_FULLSCREEN)
cv2.setWindowProperty("Hand Tracking", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.flip(frame, 1)  # 🔄 Mirror the frame
    hands, frame = detector.findHands(frame)  # 🤖 Detect hands

    if hands:
        y_position = 30  # Starting vertical position for text
        for hand in hands:
            handType = hand["type"]  # Left or Right
            fingers = detector.fingersUp(hand)  # Check raised fingers
            fingerCount = fingers.count(1)  # Count raised fingers

            # List of raised fingers
            raisedFingers = [fingerNames[i] for i in range(5) if fingers[i] == 1]
            raisedFingersText = ", ".join(raisedFingers) if raisedFingers else "None"

            # Set text color: green for left hand, blue for right hand
            color = (0, 255, 0) if handType == "Left" else (255, 0, 0)

            # Display hand type and finger count
            cv2.putText(frame, f'{handType} Hand - {fingerCount} fingers', (20, y_position),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2, cv2.LINE_AA)
            y_position += 25
            # Display which fingers are raised
            cv2.putText(frame, f'Raised: {raisedFingersText}', (20, y_position),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 255), 2, cv2.LINE_AA)
            y_position += 30  # Prevent text overlap

            # Print the finger state in console
            print(f'{handType} Hand - Fingers: {fingers}')

    # Show the video
    cv2.imshow("Hand Tracking", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Left Hand - Fingers: [1, 1, 1, 0, 0]
# Left Hand - Fingers: [1, 1, 1, 1, 0]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 1, 1, 1, 1]
# Left Hand - Fingers: [1, 0, 1, 0, 0]
# Left Hand - Fingers: [1, 1, 0, 0, 0]
# Left Hand - Fingers: [1, 1, 0, 0, 0]
# Left Hand - Fingers: [1, 1, 1, 0, 0]
# ...

# %% [markdown]
# # Graph

# %%
import cv2
import numpy as np
from cvzone.HandTrackingModule import HandDetector

# เปิดกล้อง
cap = cv2.VideoCapture(0)
detector = HandDetector(detectionCon=0.9, maxHands=2)

# ชื่อของนิ้ว
fingerNames = ["Thumb", "Index", "Middle", "Ring", "Pinky"]

# ตัวนับจำนวนครั้งที่นิ้วถูกยกขึ้น
fingerCountDict = {finger: 0 for finger in fingerNames}

cv2.namedWindow("Hand Tracking", cv2.WND_PROP_FULLSCREEN)
cv2.setWindowProperty("Hand Tracking", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.flip(frame, 1)
    hands, frame = detector.findHands(frame)

    if hands:
        y_position = 30
        for hand in hands:
            handType = hand["type"]
            fingers = detector.fingersUp(hand)

            # อัปเดตตัวนับของนิ้วที่ถูกยกขึ้น
            for i in range(5):
                if fingers[i] == 1:
                    fingerCountDict[fingerNames[i]] += 1

            # กำหนดสีของข้อความ
            color = (0, 255, 0) if handType == "Left" else (255, 0, 0)

            # แสดงข้อมูลบนหน้าจอ
            cv2.putText(frame, f'{handType} Hand - {fingers.count(1)} fingers', 
                        (20, y_position), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
            y_position += 30

            # แสดงชื่อของนิ้วที่ยกขึ้น
            raisedFingers = [fingerNames[i] for i in range(5) if fingers[i] == 1]
            raisedFingersText = ", ".join(raisedFingers) if raisedFingers else "None"
            cv2.putText(frame, f'Raised: {raisedFingersText}', 
                        (20, y_position), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
            y_position += 30  # เพิ่มระยะห่างระหว่างบรรทัด

    # แสดงผลภาพ
    cv2.imshow("Hand Tracking", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# แสดงกราฟสถิติของนิ้วที่ถูกยกขึ้น
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
plt.bar(fingerCountDict.keys(), fingerCountDict.values(), color=['red', 'blue', 'green', 'purple', 'orange'])
plt.xlabel("Finger")
plt.ylabel("Count")
plt.title("Finger Raise Frequency")
plt.xticks(rotation=45)  # หมุนชื่อของนิ้วให้ชัดเจน
plt.show()

# %%
import cv2
import numpy as np
from cvzone.HandTrackingModule import HandDetector
import matplotlib.pyplot as plt

# เปิดกล้อง
cap = cv2.VideoCapture(0)
detector = HandDetector(detectionCon=0.95, maxHands=2)  # เพิ่ม detectionCon ให้สูงขึ้น

# ชื่อของนิ้ว
fingerNames = ["Thumb", "Index", "Middle", "Ring", "Pinky"]

# ตัวนับจำนวนครั้งที่นิ้วถูกยกขึ้น
fingerCountDict = {finger: 0 for finger in fingerNames}

cv2.namedWindow("Hand Tracking", cv2.WND_PROP_FULLSCREEN)
cv2.setWindowProperty("Hand Tracking", cv2.WND_PROP_FULLSCREEN, cv2.WINDOW_FULLSCREEN)

# เพิ่มการกรองข้อมูล
previous_fingers = [0] * 5  # เก็บข้อมูลการยกนิ้วในเฟรมก่อนหน้า
correct_predictions = 0
total_frames = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break

    frame = cv2.flip(frame, 1)
    hands, frame = detector.findHands(frame)

    if hands:
        y_position = 30
        for hand in hands:
            handType = hand["type"]
            fingers = detector.fingersUp(hand)

            # อัปเดตตัวนับของนิ้วที่ถูกยกขึ้น
            for i in range(5):
                if fingers[i] == 1:
                    fingerCountDict[fingerNames[i]] += 1

            # ตรวจจับนิ้วที่ยกขึ้นและกรองผลที่ได้
            raisedFingers = [fingerNames[i] for i in range(5) if fingers[i] == 1]
            correct_predictions += sum([previous_fingers[i] == 1 and fingers[i] == 1 for i in range(5)])

            # เก็บข้อมูลในเฟรมปัจจุบัน
            previous_fingers = fingers

            # กำหนดสีของข้อความ
            color = (0, 255, 0) if handType == "Left" else (255, 0, 0)

            # แสดงข้อมูลบนหน้าจอ
            cv2.putText(frame, f'{handType} Hand - {fingers.count(1)} fingers', 
                        (20, y_position), cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)
            y_position += 30

            # แสดงชื่อของนิ้วที่ยกขึ้น
            raisedFingersText = ", ".join(raisedFingers) if raisedFingers else "None"
            cv2.putText(frame, f'Raised: {raisedFingersText}', 
                        (20, y_position), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 255), 2)
            y_position += 30  # เพิ่มระยะห่างระหว่างบรรทัด

    # แสดงผลภาพ
    cv2.imshow("Hand Tracking", frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    total_frames += 1

cap.release()
cv2.destroyAllWindows()

# คำนวณ Accuracy
accuracy = correct_predictions / total_frames * 100 if total_frames > 0 else 0
print(f"Accuracy: {accuracy:.2f}%")

# แสดงกราฟสถิติของนิ้วที่ถูกยกขึ้น
plt.figure(figsize=(8, 5))
plt.bar(fingerCountDict.keys(), fingerCountDict.values(), color=['red', 'blue', 'green', 'purple', 'orange'])
plt.xlabel("Finger")
plt.ylabel("Count")
plt.title("Finger Raise Frequency")
plt.xticks(rotation=45)  # หมุนชื่อของนิ้วให้ชัดเจน
plt.show()
# Out:
# Accuracy: 153.10%
